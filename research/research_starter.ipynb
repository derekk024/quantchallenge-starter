# %% [markdown]
# # Getting Started: Market Research
# This Jupyter notebook is a quick demonstration on how to get started on the market research section.

# %% [markdown]
# ## 1) Download Data
# Please download the train and test data and place it within the ./research/data path. If you've placed it in the correct place, you should see the following cell work:

# %%
# %pip install tensorflow

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge, LinearRegression
from sklearn.metrics import r2_score
import lightgbm as lgb


train = pd.read_csv('./data/train.csv')
test = pd.read_csv('./data/test.csv')
train_new = pd.read_csv('./data/train_new.csv')
test_new = pd.read_csv('./data/test_new.csv')

train = pd.concat([train, train_new], axis=1)
test = pd.concat([test, test_new], axis=1)
train = train.fillna(train.mean())
test = test.fillna(test.mean())

features = [c for c in train.columns if c not in ["Y1", "Y2"]]

# X = train[features].values
# X_test = test[features].values
y2 = train["Y2"].values

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input

from sklearn.model_selection import train_test_split

scaler = StandardScaler()
X = scaler.fit_transform(train[features].values)
X_test = scaler.transform(test[features].values)

n_features = X.shape[1]

mlp_model = Sequential([
    Input(shape=(n_features,)),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(64, activation='relu'),
    Dropout(0.3),
    Dense(1)
])


mlp_model.compile(optimizer='adam', loss='mse')

X_train, X_val, y2_train, y2_val = train_test_split(X, y2, test_size=0.2, random_state=42, shuffle = True)
# split = int(0.8 * len(X))
# X_train, X_val = X[:split], X[split:]
# y2_train, y2_val = y2[:split], y2[split:]
#50 and 64
hist = mlp_model.fit(X_train, y2_train, 
                     epochs=200, 
                     batch_size=128, 
                     validation_data=(X_val, y2_val), 
                     verbose=1)

y2_pred = mlp_model.predict(X_val)
r2 = r2_score(y2_val, y2_pred)
print(f"Validation R² Score: {r2}")
# Out:
# Epoch 1/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.3964 - val_loss: 0.3005
# Epoch 2/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3068 - val_loss: 0.2484
# Epoch 3/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2856 - val_loss: 0.2523
# Epoch 4/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2778 - val_loss: 0.2370
# Epoch 5/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2677 - val_loss: 0.2283
# Epoch 6/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2631 - val_loss: 0.2156
# Epoch 7/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2492 - val_loss: 0.2315
# Epoch 8/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2589 - val_loss: 0.2377
# Epoch 9/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2537 - val_loss: 0.2237
# Epoch 10/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2569 - val_loss: 0.2243
# Epoch 11/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2480 - val_loss: 0.2248
# Epoch 12/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2526 - val_loss: 0.2190
# Epoch 13/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2463 - val_loss: 0.2550
# Epoch 14/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2464 - val_loss: 0.2145
# Epoch 15/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2401 - val_loss: 0.2343
# Epoch 16/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2396 - val_loss: 0.2153
# Epoch 17/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2439 - val_loss: 0.2241
# Epoch 18/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2467 - val_loss: 0.2130
# Epoch 19/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2396 - val_loss: 0.2268
# Epoch 20/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2378 - val_loss: 0.2260
# Epoch 21/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2381 - val_loss: 0.2156
# Epoch 22/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2278 - val_loss: 0.2152
# Epoch 23/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2371 - val_loss: 0.2120
# Epoch 24/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2389 - val_loss: 0.2074
# Epoch 25/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2339 - val_loss: 0.2321
# Epoch 26/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2284 - val_loss: 0.2149
# Epoch 27/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2320 - val_loss: 0.2229
# Epoch 28/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2305 - val_loss: 0.2032
# Epoch 29/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2335 - val_loss: 0.2282
# Epoch 30/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2293 - val_loss: 0.2223
# Epoch 31/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2285 - val_loss: 0.2240
# Epoch 32/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2315 - val_loss: 0.2189
# Epoch 33/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2322 - val_loss: 0.2237
# Epoch 34/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2306 - val_loss: 0.2131
# Epoch 35/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.2246 - val_loss: 0.2398
# Epoch 36/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2253 - val_loss: 0.2029
# Epoch 37/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2247 - val_loss: 0.2008
# Epoch 38/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2253 - val_loss: 0.2152
# Epoch 39/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2228 - val_loss: 0.2140
# Epoch 40/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2264 - val_loss: 0.2234
# Epoch 41/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2229 - val_loss: 0.2014
# Epoch 42/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2299 - val_loss: 0.2152
# Epoch 43/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2147 - val_loss: 0.2073
# Epoch 44/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2213 - val_loss: 0.2358
# Epoch 45/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2256 - val_loss: 0.2056
# Epoch 46/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2231 - val_loss: 0.2112
# Epoch 47/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2195 - val_loss: 0.2227
# Epoch 48/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2219 - val_loss: 0.2253
# Epoch 49/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2220 - val_loss: 0.2173
# Epoch 50/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2241 - val_loss: 0.2135
# Epoch 51/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2228 - val_loss: 0.2205
# Epoch 52/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2159 - val_loss: 0.2042
# Epoch 53/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2201 - val_loss: 0.2043
# Epoch 54/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2164 - val_loss: 0.2023
# Epoch 55/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2130 - val_loss: 0.2100
# Epoch 56/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2112 - val_loss: 0.2065
# Epoch 57/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2115 - val_loss: 0.2117
# Epoch 58/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2135 - val_loss: 0.2169
# Epoch 59/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2115 - val_loss: 0.2124
# Epoch 60/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2120 - val_loss: 0.2110
# Epoch 61/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2171 - val_loss: 0.2149
# Epoch 62/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2187 - val_loss: 0.2360
# Epoch 63/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2230 - val_loss: 0.2117
# Epoch 64/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2139 - val_loss: 0.2139
# Epoch 65/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2177 - val_loss: 0.2324
# Epoch 66/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2221 - val_loss: 0.2152
# Epoch 67/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2114 - val_loss: 0.2238
# Epoch 68/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2150 - val_loss: 0.1961
# Epoch 69/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2171 - val_loss: 0.2058
# Epoch 70/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2141 - val_loss: 0.2101
# Epoch 71/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.2137 - val_loss: 0.2180
# Epoch 72/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2139 - val_loss: 0.2073
# Epoch 73/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2118 - val_loss: 0.2382
# Epoch 74/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2178 - val_loss: 0.1989
# Epoch 75/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2095 - val_loss: 0.2099
# Epoch 76/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2108 - val_loss: 0.2262
# Epoch 77/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2140 - val_loss: 0.2084
# Epoch 78/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2117 - val_loss: 0.2077
# Epoch 79/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2062 - val_loss: 0.2004
# Epoch 80/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2184 - val_loss: 0.2100
# Epoch 81/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2112 - val_loss: 0.1980
# Epoch 82/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2113 - val_loss: 0.2052
# Epoch 83/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2149 - val_loss: 0.2029
# Epoch 84/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2091 - val_loss: 0.2323
# Epoch 85/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2163 - val_loss: 0.2138
# Epoch 86/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2047 - val_loss: 0.2051
# Epoch 87/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2124 - val_loss: 0.2370
# Epoch 88/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2091 - val_loss: 0.2229
# Epoch 89/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2111 - val_loss: 0.2105
# Epoch 90/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2094 - val_loss: 0.2186
# Epoch 91/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2066 - val_loss: 0.2089
# Epoch 92/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2055 - val_loss: 0.2114
# Epoch 93/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2006 - val_loss: 0.2090
# Epoch 94/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2081 - val_loss: 0.2087
# Epoch 95/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2076 - val_loss: 0.2105
# Epoch 96/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2066 - val_loss: 0.2037
# Epoch 97/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2025 - val_loss: 0.2058
# Epoch 98/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2026 - val_loss: 0.2088
# Epoch 99/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2086 - val_loss: 0.2036
# Epoch 100/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2059 - val_loss: 0.2130
# Epoch 101/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2096 - val_loss: 0.2111
# Epoch 102/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1988 - val_loss: 0.2133
# Epoch 103/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2012 - val_loss: 0.2044
# Epoch 104/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2069 - val_loss: 0.2424
# Epoch 105/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2107 - val_loss: 0.2063
# Epoch 106/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2071 - val_loss: 0.2076
# Epoch 107/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2151 - val_loss: 0.2130
# Epoch 108/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2096 - val_loss: 0.2339
# Epoch 109/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2033 - val_loss: 0.2200
# Epoch 110/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2028 - val_loss: 0.2108
# Epoch 111/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2083 - val_loss: 0.2199
# Epoch 112/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2030 - val_loss: 0.2178
# Epoch 113/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2076 - val_loss: 0.2014
# Epoch 114/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2007 - val_loss: 0.2178
# Epoch 115/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2189 - val_loss: 0.2033
# Epoch 116/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1992 - val_loss: 0.2097
# Epoch 117/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1979 - val_loss: 0.2132
# Epoch 118/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2074 - val_loss: 0.2094
# Epoch 119/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2002 - val_loss: 0.2192
# Epoch 120/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2004 - val_loss: 0.2044
# Epoch 121/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2001 - val_loss: 0.2173
# Epoch 122/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1992 - val_loss: 0.2294
# Epoch 123/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2048 - val_loss: 0.2168
# Epoch 124/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2044 - val_loss: 0.2231
# Epoch 125/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2019 - val_loss: 0.2204
# Epoch 126/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2085 - val_loss: 0.2146
# Epoch 127/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1950 - val_loss: 0.2012
# Epoch 128/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2101 - val_loss: 0.2378
# Epoch 129/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1984 - val_loss: 0.2141
# Epoch 130/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2010 - val_loss: 0.2031
# Epoch 131/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2005 - val_loss: 0.2120
# Epoch 132/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2010 - val_loss: 0.2090
# Epoch 133/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2080 - val_loss: 0.2213
# Epoch 134/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.2031 - val_loss: 0.2326
# Epoch 135/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2037 - val_loss: 0.2075
# Epoch 136/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2013 - val_loss: 0.2219
# Epoch 137/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2015 - val_loss: 0.2178
# Epoch 138/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1959 - val_loss: 0.2189
# Epoch 139/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1992 - val_loss: 0.2082
# Epoch 140/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2003 - val_loss: 0.2121
# Epoch 141/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2098 - val_loss: 0.2159
# Epoch 142/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1985 - val_loss: 0.2062
# Epoch 143/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1978 - val_loss: 0.2099
# Epoch 144/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2004 - val_loss: 0.2184
# Epoch 145/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2028 - val_loss: 0.2257
# Epoch 146/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2003 - val_loss: 0.2114
# Epoch 147/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2029 - val_loss: 0.2203
# Epoch 148/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2016 - val_loss: 0.2031
# Epoch 149/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2004 - val_loss: 0.2171
# Epoch 150/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2026 - val_loss: 0.2123
# Epoch 151/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2003 - val_loss: 0.2110
# Epoch 152/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2003 - val_loss: 0.2000
# Epoch 153/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1987 - val_loss: 0.2126
# Epoch 154/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1983 - val_loss: 0.2236
# Epoch 155/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2027 - val_loss: 0.2251
# Epoch 156/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2051 - val_loss: 0.2066
# Epoch 157/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1966 - val_loss: 0.2008
# Epoch 158/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1989 - val_loss: 0.2243
# Epoch 159/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1972 - val_loss: 0.2105
# Epoch 160/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1956 - val_loss: 0.1996
# Epoch 161/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1984 - val_loss: 0.2071
# Epoch 162/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2089 - val_loss: 0.2107
# Epoch 163/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.2005 - val_loss: 0.2129
# Epoch 164/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2009 - val_loss: 0.2229
# Epoch 165/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1977 - val_loss: 0.2198
# Epoch 166/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1994 - val_loss: 0.2148
# Epoch 167/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2019 - val_loss: 0.2344
# Epoch 168/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1942 - val_loss: 0.2098
# Epoch 169/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1931 - val_loss: 0.2396
# Epoch 170/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2032 - val_loss: 0.2115
# Epoch 171/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1987 - val_loss: 0.2187
# Epoch 172/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.2031 - val_loss: 0.2143
# Epoch 173/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1984 - val_loss: 0.2204
# Epoch 174/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1937 - val_loss: 0.2464
# Epoch 175/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1979 - val_loss: 0.2336
# Epoch 176/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1946 - val_loss: 0.2058
# Epoch 177/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1956 - val_loss: 0.2053
# Epoch 178/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1962 - val_loss: 0.1921
# Epoch 179/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1908 - val_loss: 0.2337
# Epoch 180/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1963 - val_loss: 0.2497
# Epoch 181/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1928 - val_loss: 0.2303
# Epoch 182/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.2040 - val_loss: 0.2147
# Epoch 183/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1890 - val_loss: 0.2121
# Epoch 184/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2010 - val_loss: 0.2505
# Epoch 185/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1984 - val_loss: 0.2155
# Epoch 186/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1962 - val_loss: 0.2265
# Epoch 187/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.2017 - val_loss: 0.2158
# Epoch 188/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1966 - val_loss: 0.2172
# Epoch 189/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1979 - val_loss: 0.2278
# Epoch 190/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1963 - val_loss: 0.2170
# Epoch 191/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1938 - val_loss: 0.2021
# Epoch 192/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1951 - val_loss: 0.2127
# Epoch 193/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1954 - val_loss: 0.2262
# Epoch 194/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1948 - val_loss: 0.2245
# Epoch 195/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1942 - val_loss: 0.2020
# Epoch 196/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1934 - val_loss: 0.2103
# Epoch 197/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1918 - val_loss: 0.2191
# Epoch 198/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2126 - val_loss: 0.2450
# Epoch 199/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.2020 - val_loss: 0.2074
# Epoch 200/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1985 - val_loss: 0.2275
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Validation R² Score: 0.7446408235022883
